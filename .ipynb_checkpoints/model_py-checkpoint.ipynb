# %%
import sys
# !{sys.executable} -m pip install pandas numpy flask pycaret
# Out:
# Running cells with '.venv (Python 3.10.11)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/ketak/OneDrive/Desktop/5th Semester/DevOps/devops_mini_project-main/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
# !pip install pandas numpy pycaret flask
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\ketak\appdata\roaming\python\python312\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\ketak\appdata\roaming\python\python312\site-packages (1.26.2)
# Requirement already satisfied: pycaret in c:\users\ketak\appdata\roaming\python\python312\site-packages (3.3.0)
# Requirement already satisfied: flask in c:\users\ketak\appdata\roaming\python\python312\site-packages (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (8.26.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (8.1.8)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: jinja2>=3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (3.1.5)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (2.0.5)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (0.62.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (6.3.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (0.14.5)
# Requirement already satisfied: sktime>=0.26.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from matplotlib<3.8.0->pycaret) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from matplotlib<3.8.0->pycaret) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from matplotlib<3.8.0->pycaret) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from matplotlib<3.8.0->pycaret) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from matplotlib<3.8.0->pycaret) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from matplotlib<3.8.0->pycaret) (3.1.4)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from flask) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from flask) (1.9.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from scikit-learn>1.4.0->pycaret) (3.5.0)
# Requirement already satisfied: colorama in c:\users\ketak\appdata\roaming\python\python312\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: decorator in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipython>=5.5.0->pycaret) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipython>=5.5.0->pycaret) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\ketak\appdata\roaming\python\python312\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: choreographer>=1.1.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from kaleido>=0.2.1->pycaret) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from kaleido>=0.2.1->pycaret) (3.10.15)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from choreographer>=1.1.1->kaleido>=0.2.1->pycaret) (3.20.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.2.2)
# Requirement already satisfied: pywin32>=300 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (306)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from numba>=0.55.0->pycaret) (0.45.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from plotly>=5.14.0->pycaret) (1.24.1)
# Requirement already satisfied: dash>=2.11.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.3.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (4.12.2)
# Requirement already satisfied: retrying in c:\users\ketak\appdata\roaming\python\python312\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\ketak\appdata\roaming\python\python312\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\ketak\appdata\roaming\python\python312\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (80.9.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pmdarima>=2.0.4->pycaret) (3.2.1)
# Requirement already satisfied: urllib3 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pmdarima>=2.0.4->pycaret) (2.3.0)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (8.4.1)
# Requirement already satisfied: iniconfig>=1 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from requests>=2.27.1->pycaret) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from requests>=2.27.1->pycaret) (2025.1.31)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from sktime>=0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ketak\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\ketak\appdata\roaming\python\python312\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.3)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Program Files\Python312\python.exe -m pip install --upgrade pip

# %%
# 1. Install PyCaret if not installed
# pip install pycaret

import pandas as pd
from pycaret.regression import *

# 2. Load your Kaggle data
# Assuming you've downloaded the CSV from Kaggle and saved it locally
df = pd.read_csv('coffee_sales.csv')  # change path accordingly

# 3. Data preprocessing: Example checks
print(df.head())
print(df.info())
print(df.isna().sum())

# (Optional) Do any manual preprocessing: fill missing values, convert categorical dtypes etc.
# e.g. df['region'] = df['region'].astype('category')

# 4. PyCaret setup
reg = setup(
    data = df,
    target = 'money',   # change to your target column
    session_id = 123,
    fold_strategy = 'kfold',
    fold = 5,
    numeric_features = ['hour_of_day'],   # list your numeric features
    categorical_features = ['coffee_name', 'Time_of_Day','Weekday','Month_name'],       # list your categorical features
    normalize = True,           # optional: normalize numeric features
    transformation = True,      # optional: transform features to better distribution
    transform_target = False,   # optional: transform target if needed
)

# 5. Compare models
best_model = compare_models(sort = 'MAE')  # you can change metric

# 6. Create/tune model: example with Random Forest
rf = create_model('rf')
tuned_rf = tune_model(rf, optimize = 'MAE')

# 7. Evaluate
evaluate_model(tuned_rf)

# 8. Finalize (train on full data)
final_rf = finalize_model(tuned_rf)

# 9. Predict on new/unseen data
# Let's say you have a test dataset or want to predict on the same dataset
predictions = predict_model(final_rf, data=df)
print(predictions.head())

# 10. Save model
save_model(final_rf, 'coffee_sales_rf_model')

# To load later:
# loaded_model = load_model('coffee_sales_rf_model')
# Out:
#    hour_of_day  money    coffee_name Time_of_Day Weekday Month_name
# 0           10   38.7          Latte     Morning     Fri        Mar
# 1           12   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2           12   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3           13   28.9      Americano   Afternoon     Fri        Mar
# 4           13   38.7          Latte   Afternoon     Fri        Mar
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3547 entries, 0 to 3546
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  3547 non-null   int64
#  1   money        3547 non-null   float64
#  2   coffee_name  3547 non-null   object
#  3   Time_of_Day  3547 non-null   object
#  4   Weekday      3547 non-null   object
#  5   Month_name   3547 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 166.4+ KB
# None
# hour_of_day    0
# money          0
# coffee_name    0
# Time_of_Day    0
# Weekday        0
# Month_name     0
# dtype: int64
# <style type="text/css">
# #T_e1363_row9_col1, #T_e1363_row15_col1, #T_e1363_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e1363">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1363_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e1363_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1363_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1363_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e1363_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e1363_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e1363_row1_col1" class="data row1 col1" >money</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e1363_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e1363_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e1363_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e1363_row3_col1" class="data row3 col1" >(3547, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e1363_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e1363_row4_col1" class="data row4 col1" >(3547, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e1363_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e1363_row5_col1" class="data row5 col1" >(2482, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e1363_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e1363_row6_col1" class="data row6 col1" >(1065, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e1363_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e1363_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e1363_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_e1363_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e1363_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_e1363_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e1363_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_e1363_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e1363_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_e1363_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e1363_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_e1363_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e1363_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_e1363_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e1363_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_e1363_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e1363_row15_col0" class="data row15 col0" >Transformation</td>
#       <td id="T_e1363_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e1363_row16_col0" class="data row16 col0" >Transformation method</td>
#       <td id="T_e1363_row16_col1" class="data row16 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e1363_row17_col0" class="data row17 col0" >Normalize</td>
#       <td id="T_e1363_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e1363_row18_col0" class="data row18 col0" >Normalize method</td>
#       <td id="T_e1363_row18_col1" class="data row18 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e1363_row19_col0" class="data row19 col0" >Fold Generator</td>
#       <td id="T_e1363_row19_col1" class="data row19 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e1363_row20_col0" class="data row20 col0" >Fold Number</td>
#       <td id="T_e1363_row20_col1" class="data row20 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e1363_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_e1363_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e1363_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_e1363_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e1363_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_e1363_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e1363_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_e1363_row24_col1" class="data row24 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e1363_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e1363_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_e1363_row25_col1" class="data row25 col1" >9bb2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f2d4b th {
#   text-align: left;
# }
# #T_f2d4b_row0_col0, #T_f2d4b_row0_col2, #T_f2d4b_row0_col3, #T_f2d4b_row0_col4, #T_f2d4b_row0_col5, #T_f2d4b_row1_col0, #T_f2d4b_row1_col1, #T_f2d4b_row1_col2, #T_f2d4b_row1_col3, #T_f2d4b_row1_col4, #T_f2d4b_row1_col5, #T_f2d4b_row1_col6, #T_f2d4b_row2_col0, #T_f2d4b_row2_col1, #T_f2d4b_row2_col2, #T_f2d4b_row2_col3, #T_f2d4b_row2_col4, #T_f2d4b_row2_col5, #T_f2d4b_row2_col6, #T_f2d4b_row3_col0, #T_f2d4b_row3_col1, #T_f2d4b_row3_col2, #T_f2d4b_row3_col3, #T_f2d4b_row3_col4, #T_f2d4b_row3_col5, #T_f2d4b_row3_col6, #T_f2d4b_row4_col0, #T_f2d4b_row4_col1, #T_f2d4b_row4_col2, #T_f2d4b_row4_col3, #T_f2d4b_row4_col4, #T_f2d4b_row4_col5, #T_f2d4b_row4_col6, #T_f2d4b_row5_col0, #T_f2d4b_row5_col1, #T_f2d4b_row5_col2, #T_f2d4b_row5_col3, #T_f2d4b_row5_col4, #T_f2d4b_row5_col5, #T_f2d4b_row5_col6, #T_f2d4b_row6_col0, #T_f2d4b_row6_col1, #T_f2d4b_row6_col2, #T_f2d4b_row6_col3, #T_f2d4b_row6_col4, #T_f2d4b_row6_col5, #T_f2d4b_row6_col6, #T_f2d4b_row7_col0, #T_f2d4b_row7_col1, #T_f2d4b_row7_col2, #T_f2d4b_row7_col3, #T_f2d4b_row7_col4, #T_f2d4b_row7_col5, #T_f2d4b_row7_col6, #T_f2d4b_row8_col0, #T_f2d4b_row8_col1, #T_f2d4b_row8_col6, #T_f2d4b_row9_col0, #T_f2d4b_row9_col1, #T_f2d4b_row9_col2, #T_f2d4b_row9_col3, #T_f2d4b_row9_col4, #T_f2d4b_row9_col5, #T_f2d4b_row9_col6, #T_f2d4b_row10_col0, #T_f2d4b_row10_col1, #T_f2d4b_row10_col2, #T_f2d4b_row10_col3, #T_f2d4b_row10_col4, #T_f2d4b_row10_col5, #T_f2d4b_row10_col6, #T_f2d4b_row11_col0, #T_f2d4b_row11_col1, #T_f2d4b_row11_col2, #T_f2d4b_row11_col3, #T_f2d4b_row11_col4, #T_f2d4b_row11_col5, #T_f2d4b_row11_col6, #T_f2d4b_row12_col0, #T_f2d4b_row12_col1, #T_f2d4b_row12_col2, #T_f2d4b_row12_col3, #T_f2d4b_row12_col4, #T_f2d4b_row12_col5, #T_f2d4b_row12_col6, #T_f2d4b_row13_col0, #T_f2d4b_row13_col1, #T_f2d4b_row13_col2, #T_f2d4b_row13_col3, #T_f2d4b_row13_col4, #T_f2d4b_row13_col5, #T_f2d4b_row13_col6, #T_f2d4b_row14_col0, #T_f2d4b_row14_col1, #T_f2d4b_row14_col2, #T_f2d4b_row14_col3, #T_f2d4b_row14_col4, #T_f2d4b_row14_col5, #T_f2d4b_row14_col6, #T_f2d4b_row15_col0, #T_f2d4b_row15_col1, #T_f2d4b_row15_col2, #T_f2d4b_row15_col3, #T_f2d4b_row15_col4, #T_f2d4b_row15_col5, #T_f2d4b_row15_col6, #T_f2d4b_row16_col0, #T_f2d4b_row16_col1, #T_f2d4b_row16_col2, #T_f2d4b_row16_col3, #T_f2d4b_row16_col4, #T_f2d4b_row16_col5, #T_f2d4b_row16_col6, #T_f2d4b_row17_col0, #T_f2d4b_row17_col1, #T_f2d4b_row17_col2, #T_f2d4b_row17_col3, #T_f2d4b_row17_col4, #T_f2d4b_row17_col5, #T_f2d4b_row17_col6 {
#   text-align: left;
# }
# #T_f2d4b_row0_col1, #T_f2d4b_row0_col6, #T_f2d4b_row8_col2, #T_f2d4b_row8_col3, #T_f2d4b_row8_col4, #T_f2d4b_row8_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_f2d4b_row0_col7, #T_f2d4b_row1_col7, #T_f2d4b_row2_col7, #T_f2d4b_row3_col7, #T_f2d4b_row4_col7, #T_f2d4b_row5_col7, #T_f2d4b_row6_col7, #T_f2d4b_row7_col7, #T_f2d4b_row8_col7, #T_f2d4b_row9_col7, #T_f2d4b_row10_col7, #T_f2d4b_row11_col7, #T_f2d4b_row12_col7, #T_f2d4b_row14_col7, #T_f2d4b_row15_col7, #T_f2d4b_row16_col7, #T_f2d4b_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_f2d4b_row13_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_f2d4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2d4b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f2d4b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f2d4b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f2d4b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f2d4b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f2d4b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f2d4b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_f2d4b_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2d4b_level0_row0" class="row_heading level0 row0" >huber</th>
#       <td id="T_f2d4b_row0_col0" class="data row0 col0" >Huber Regressor</td>
#       <td id="T_f2d4b_row0_col1" class="data row0 col1" >0.2432</td>
#       <td id="T_f2d4b_row0_col2" class="data row0 col2" >0.7631</td>
#       <td id="T_f2d4b_row0_col3" class="data row0 col3" >0.8705</td>
#       <td id="T_f2d4b_row0_col4" class="data row0 col4" >0.9678</td>
#       <td id="T_f2d4b_row0_col5" class="data row0 col5" >0.0276</td>
#       <td id="T_f2d4b_row0_col6" class="data row0 col6" >0.0074</td>
#       <td id="T_f2d4b_row0_col7" class="data row0 col7" >0.0880</td>
#     </tr>
#     <tr>
#       <th id="T_f2d4b_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T
level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_b6802_row6_col0" class="data row6 col0" >0.0200</td>
#       <td id="T_b6802_row6_col1" class="data row6 col1" >0.0618</td>
#       <td id="T_b6802_row6_col2" class="data row6 col2" >0.0397</td>
#       <td id="T_b6802_row6_col3" class="data row6 col3" >0.0032</td>
#       <td id="T_b6802_row6_col4" class="data row6 col4" >0.0014</td>
#       <td id="T_b6802_row6_col5" class="data row6 col5" >0.0006</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e7ad6_row5_col0, #T_e7ad6_row5_col1, #T_e7ad6_row5_col2, #T_e7ad6_row5_col3, #T_e7ad6_row5_col4, #T_e7ad6_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e7ad6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7ad6_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e7ad6_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e7ad6_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e7ad6_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e7ad6_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e7ad6_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7ad6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7ad6_row0_col0" class="data row0 col0" >0.8960</td>
#       <td id="T_e7ad6_row0_col1" class="data row0 col1" >1.4665</td>
#       <td id="T_e7ad6_row0_col2" class="data row0 col2" >1.2110</td>
#       <td id="T_e7ad6_row0_col3" class="data row0 col3" >0.9363</td>
#       <td id="T_e7ad6_row0_col4" class="data row0 col4" >0.0419</td>
#       <td id="T_e7ad6_row0_col5" class="data row0 col5" >0.0307</td>
#     </tr>
#     <tr>
#       <th id="T_e7ad6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7ad6_row1_col0" class="data row1 col0" >0.9320</td>
#       <td id="T_e7ad6_row1_col1" class="data row1 col1" >1.5269</td>
#       <td id="T_e7ad6_row1_col2" class="data row1 col2" >1.2357</td>
#       <td id="T_e7ad6_row1_col3" class="data row1 col3" >0.9340</td>
#       <td id="T_e7ad6_row1_col4" class="data row1 col4" >0.0406</td>
#       <td id="T_e7ad6_row1_col5" class="data row1 col5" >0.0308</td>
#     </tr>
#     <tr>
#       <th id="T_e7ad6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7ad6_row2_col0" class="data row2 col0" >0.9027</td>
#       <td id="T_e7ad6_row2_col1" class="data row2 col1" >1.5119</td>
#       <td id="T_e7ad6_row2_col2" class="data row2 col2" >1.2296</td>
#       <td id="T_e7ad6_row2_col3" class="data row2 col3" >0.9379</td>
#       <td id="T_e7ad6_row2_col4" class="data row2 col4" >0.0426</td>
#       <td id="T_e7ad6_row2_col5" class="data row2 col5" >0.0309</td>
#     </tr>
#     <tr>
#       <th id="T_e7ad6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7ad6_row3_col0" class="data row3 col0" >0.9337</td>
#       <td id="T_e7ad6_row3_col1" class="data row3 col1" >1.6123</td>
#       <td id="T_e7ad6_row3_col2" class="data row3 col2" >1.2698</td>
#       <td id="T_e7ad6_row3_col3" class="data row3 col3" >0.9353</td>
#       <td id="T_e7ad6_row3_col4" class="data row3 col4" >0.0450</td>
#       <td id="T_e7ad6_row3_col5" class="data row3 col5" >0.0324</td>
#     </tr>
#     <tr>
#       <th id="T_e7ad6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e7ad6_row4_col0" class="data row4 col0" >0.8800</td>
#       <td id="T_e7ad6_row4_col1" class="data row4 col1" >1.4251</td>
#       <td id="T_e7ad6_row4_col2" class="data row4 col2" >1.1938</td>
#       <td id="T_e7ad6_row4_col3" class="data row4 col3" >0.9386</td>
#       <td id="T_e7ad6_row4_col4" class="data row4 col4" >0.0422</td>
#       <td id="T_e7ad6_row4_col5" class="data row4 col5" >0.0304</td>
#     </tr>
#     <tr>
#       <th id="T_e7ad6_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_e7ad6_row5_col0" class="data row5 col0" >0.9089</td>
#       <td id="T_e7ad6_row5_col1" class="data row5 col1" >1.5086</td>
#       <td id="T_e7ad6_row5_col2" class="data row5 col2" >1.2280</td>
#       <td id="T_e7ad6_row5_col3" class="data row5 col3" >0.9364</td>
#       <td id="T_e7ad6_row5_col4" class="data row5 col4" >0.0425</td>
#       <td id="T_e7ad6_row5_col5" class="data row5 col5" >0.0311</td>
#     </tr>
#     <tr>
#       <th id="T_e7ad6_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_e7ad6_row6_col0" class="data row6 col0" >0.0209</td>
#       <td id="T_e7ad6_row6_col1" class="data row6 col1" >0.0630</td>
#       <td id="T_e7ad6_row6_col2" class="data row6 col2" >0.0256</td>
#       <td id="T_e7ad6_row6_col3" class="data row6 col3" >0.0017</td>
#       <td id="T_e7ad6_row6_col4" class="data row6 col4" >0.0014</td>
#       <td id="T_e7ad6_row6_col5" class="data row6 col5" >0.0007</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# <style type="text/css">
# </style>
# <table id="T_ea2a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea2a1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ea2a1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_ea2a1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_ea2a1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_ea2a1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_ea2a1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_ea2a1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea2a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea2a1_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_ea2a1_row0_col1" class="data row0 col1" >0.1294</td>
#       <td id="T_ea2a1_row0_col2" class="data row0 col2" >0.1566</td>
#       <td id="T_ea2a1_row0_col3" class="data row0 col3" >0.3957</td>
#       <td id="T_ea2a1_row0_col4" class="data row0 col4" >0.9934</td>
#       <td id="T_ea2a1_row0_col5" class="data row0 col5" >0.0125</td>
#       <td id="T_ea2a1_row0_col6" class="data row0 col6" >0.0042</td>
#     </tr>
#   </tbody>
# </table>
#    hour_of_day    coffee_name Time_of_Day Weekday Month_name      money  \
# 0           10          Latte     Morning     Fri        Mar  38.700001
# 1           12  Hot Chocolate   Afternoon     Fri        Mar  38.700001
# 2           12  Hot Chocolate   Afternoon     Fri        Mar  38.700001
# 3           13      Americano   Afternoon     Fri        Mar  28.900000
# 4           13          Latte   Afternoon     Fri        Mar  38.700001
#
#    prediction_label
# 0         37.685210
# 1         38.459901
# 2         38.459901
# 3         27.467106
# 4         36.835899
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['hour_of_day'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['coffee_name', 'Time_of_Day',
#                                               'Weekday', 'Month_name'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['coffee...
#                                      transformer=OneHotEncoder(cols=['coffee_name',
#                                                                      'Time_of_Day',
#                                                                      'Weekday',
#                                                                      'Month_name'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('transformation',
#                   TransformerWrapper(transformer=PowerTransformer(standardize=False))),
#                  ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                  ('actual_estimator',
#                   RandomForestRegressor(n_jobs=-1, random_state=123))]),
#  'coffee_sales_rf_model.pkl')

# %%
for col in df.columns:
    print(col, df[col].apply(type).unique())
# Out:
# hour_of_day [<class 'int'>]
# money [<class 'float'>]
# coffee_name [<class 'str'>]
# Time_of_Day [<class 'str'>]
# Weekday [<class 'str'>]
# Month_name [<class 'str'>]
